# %%
import pandas as pd

# %%
df = pd.read_csv('/SGRNJ06/randd/USER/zhouyiqi/work/analysis/20250728-rd/all.csv')

# %%
filtered_df = df[df['个性化分析负责人'].astype(str).str.contains('付欣|王靖深|陈俊杰|李季|周义其', na=False)]

# %%
filtered_df
# Out:
#             uuid                                      项目编号  \
# 37    i3ehxvsif0             P24102506-中南大学湘雅医院黄老师单细胞项目（人）
# 45    i39dmo97j2              P24121302-暨南大学金老师单细胞糖基化项目（人）
# 59    i36lhpvb6y     P24112003-福建医科大学附属第一医院林老师单细胞和胞内菌项目（人）
# 136   i2h16wxdv0      P25012005-江西省肿瘤医院熊老师胞内菌单细胞+ATAC项目（人）
# 137   i2gyndpswv     P24122509-福建医科大学附属第一医院林医生单细胞和胞内菌项目（人）
# ...          ...                                       ...
# 3193  hd75g724an           P23031708-深圳市人民医院肖老师糖基化单细胞项目（人）
# 3607  h8z9oqv76k                P22022804-省人医周老师动态转录组项目（人）
# 3723  h85n1sgxw3  P22101602-福建医科大学附属第一医院陈老师单细胞和全长TCR项目（小鼠）
# 3747  h7ytm588ym                P22022804-省人医周老师动态转录组项目（人）
# 4210  h4ml2ovfe4                P22022804-省人医周老师动态转录组项目（人）
#
#                                 项目名称     关联项目编号 分析批次 项目对接人（客户方） 对接人信息  \
# 37               中南大学湘雅医院黄老师单细胞项目（人）        NaN   B2        NaN   NaN
# 45                暨南大学金老师单细胞糖基化项目（人）        NaN   B2        NaN   NaN
# ...

# %%
filtered_df.to_csv("/SGRNJ06/randd/USER/zhouyiqi/work/analysis/20250728-rd/RD.csv")

# %%
df = pd.read_csv('/SGRNJ06/randd/PROJECT/IR_group/AccuraCode_TCR/20250421_Hum0410PBMC/TCR/CK/B_Hum0410PBMC_TCR_CK_MP/05.count_vdj/B_Hum0410PBMC_TCR_CK_MP_filtered_annotations.csv')

# %%
trb = df[df['chain']=='TRB']
trb['v_gene'].unique()
# Out:
# array(['TRBV12-3', 'TRBV7-9', 'TRBV2', 'TRBV20-1', 'TRBV6-5', 'TRBV6-1',
#        'TRBV27', 'TRBV19', 'TRBV11-3', 'TRBV4-1', 'TRBV7-8', 'TRBV7-2',
#        'TRBV24-1', 'TRBV28', 'TRBV5-5', 'TRBV9', 'TRBV14', 'TRBV5-1',
#        'TRBV7-3', 'TRBV30', 'TRBV3-1', 'TRBV5-6', 'TRBV29-1', 'TRBV11-1',
#        'TRBV18', 'TRBV6-6', 'TRBV5-4', 'TRBV12-5', 'TRBV6-2', 'TRBV15',
#        'TRBV10-1', 'TRBV11-2', 'TRBV10-3', 'TRBV6-4', 'TRBV5-8',
#        'TRBV25-1', 'TRBV16', 'TRBV23-1', 'TRBV13', 'TRBV4-2', 'TRBV6-9',
#        'TRBV7-6', 'TRBV7-7', 'TRBV21-1', 'TRBV10-2', 'TRAV1-1', 'TRBV6-7',
#        'TRBV5-3', 'TRBV12-2', 'TRAV14/DV4', 'TRBV7-1', 'TRBV4-3',
#        'TRBV6-8', 'TRBV7-4', 'TRBV12-1', 'TRBV21/OR9-2', 'TRBV1',
#        'TRBV5-7'], dtype=object)

# %%
len(trb['v_gene'].unique())
# Out:
# 58
